# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# This cell copies the dataset into the `Kaggle Working Directory` for data manipulaiton

# %%
import os
import shutil

# Define source and destination directories
src_dir = "/kaggle/input/dlp-object-detection-week-10/final_dlp_data"
dest_dir = "/kaggle/working"

# Walk through the source directory
for root, dirs, files in os.walk(src_dir):
    # Compute the relative path from the source directory
    rel_path = os.path.relpath(root, src_dir)
    
    # Compute the corresponding destination path
    dest_path = os.path.join(dest_dir, rel_path)
    
    # Create the destination directory if it does not exist
    os.makedirs(dest_path, exist_ok=True)
    
    # Copy each file to the destination while maintaining structure
    for file in files:
        src_file = os.path.join(root, file)
        dest_file = os.path.join(dest_path, file)
        shutil.copy2(src_file, dest_file)  # Copy while preserving metadata

print("Files copied successfully while maintaining directory structure.")
# Out:
# Files copied successfully while maintaining directory structure.

# %% [markdown]
# * This cell creates a validation dataset from the given train dataset
# * 20% of the training data is kept for validation

# %%
import os
import random
import shutil

# Define paths
base_path = "/kaggle/working/final_dlp_data/"
train_images_path = os.path.join(base_path, "train", "images")
train_labels_path = os.path.join(base_path, "train", "labels")
val_images_path = os.path.join(base_path, "val", "images")
val_labels_path = os.path.join(base_path, "val", "labels")

# Create val directories if they don't exist
os.makedirs(val_images_path, exist_ok=True)
os.makedirs(val_labels_path, exist_ok=True)

# List all images and corresponding labels
image_files = sorted([f for f in os.listdir(train_images_path) if f.endswith((".jpeg", ".png"))])
label_files = sorted([f for f in os.listdir(train_labels_path) if f.endswith(".txt")])

# Ensure image-label pairs match
assert len(image_files) == len(label_files), "Mismatch between images and labels"

# Define split percentage
val_ratio = 0.2  # 20% for validation
val_size = int(len(image_files) * val_ratio)

# Select random samples for validation
val_indices = random.sample(range(len(image_files)), val_size)

# Move selected files to val folder
for idx in val_indices:
    img_file = image_files[idx]
    label_file = label_files[idx]

    shutil.move(os.path.join(train_images_path, img_file), os.path.join(val_images_path, img_file))
    shutil.move(os.path.join(train_labels_path, label_file), os.path.join(val_labels_path, label_file))

print(f"Moved {val_size} images and labels to validation set.")
# Out:
# Moved 1500 images and labels to validation set.

# %% [markdown]
# **Yolo Model Training**

# %%
yaml_content = """
# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]

path: /kaggle/working/final_dlp_data # dataset root dir
train: train/images # train images (relative to 'path')
val: val/images # validation images (relative to 'path')
test: test/images # test images (relative to 'path')

names:
    0: aegypti
    1: albopictus
    2: anopheles
    3: culex
    4: culiseta
    5: japonicus/koreicus
"""

# Save to a file in Kaggle
file_path = "/kaggle/working/dataset.yaml"
with open(file_path, "w") as f:
    f.write(yaml_content)

print(f"YAML file saved at: {file_path}")
# Out:
# YAML file saved at: /kaggle/working/dataset.yaml

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 25.7 MB/s eta 0:00:0000:01

# %% [markdown]
# **Training the YOLO model:**

# %%
from ultralytics import YOLO


model = YOLO("yolov9c.pt")

results = model.train(data="/kaggle/working/dataset.yaml", epochs=5, imgsz=640)
# Out:
# Ultralytics 8.3.96 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolov9c.pt, data=/kaggle/working/dataset.yaml, epochs=5, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    212864  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 1]
#   3                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#   4                  -1  1    847616  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 1]
#   5                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   6                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   7                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   8                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPELAN         [512, 512, 256]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    912640  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 256, 256, 128, 1]
#  16                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1   2988544  ultralytics.nn.modules.block.RepNCSPELAN4    [768, 512, 512, 256, 1]
#  19                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  22        [15, 18, 21]  1   5587426  ultralytics.nn.modules.head.Detect           [6, [256, 512, 512]]
# YOLOv9c summary: 358 layers, 25,533,858 parameters, 25,533,842 gradients, 103.7 GFLOPs
#
# Transferred 931/937 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/final_dlp_data/train/labels... 3196 images, 0 backgrounds, 1 corrupt:  53%|█████▎    | 3196/6000 [00:02<00:02, 1264.84it/s]/usr/local/lib/python3.10/dist-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# train: Scanning /kaggle/working/final_dlp_data/train/labels... 6000 images, 0 backgrounds, 1 corrupt: 100%|██████████| 6000/6000 [00:04<00:00, 1245.90it/s]
# train: WARNING ⚠️ /kaggle/working/final_dlp_data/train/images/120b30b0-c7db-4f0a-bead-a30424a65453.jpeg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0068]
# train: New cache created: /kaggle/working/final_dlp_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# val: Scanning /kaggle/working/final_dlp_data/val/labels... 1500 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1500/1500 [00:01<00:00, 1145.25it/s]
# val: New cache created: /kaggle/working/final_dlp_data/val/labels.cache
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5      11.2G      1.343      1.805      1.522         30        640: 100%|██████████| 375/375 [05:44<00:00,  1.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:28<00:00,  1.67it/s]
#                    all       1500       1500      0.908      0.246      0.271      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5      10.9G       1.38      1.492      1.548         35        640: 100%|██████████| 375/375 [05:43<00:00,  1.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:27<00:00,  1.70it/s]
#                    all       1500       1500      0.526      0.325      0.268      0.174
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      10.9G      1.314      1.374      1.497         33        640: 100%|██████████| 375/375 [05:36<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:24<00:00,  1.93it/s]
#                    all       1500       1500      0.913      0.266      0.306      0.206
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5      10.9G      1.237      1.254      1.437         24        640: 100%|██████████| 375/375 [05:36<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:24<00:00,  1.92it/s]
#                    all       1500       1500      0.585      0.403      0.341      0.247
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5      10.9G      1.138      1.096      1.367         26        640: 100%|██████████| 375/375 [05:35<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:24<00:00,  1.94it/s]
#                    all       1500       1500      0.597      0.411      0.365      0.269
# 5 epochs completed in 0.513 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 51.6MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 51.6MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.96 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv9c summary (fused): 156 layers, 25,323,874 parameters, 0 gradients, 102.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:25<00:00,  1.82it/s]
#                    all       1500       1500      0.597      0.412      0.365      0.269
#                aegypti          9          9          1          0     0.0791     0.0422
#             albopictus        662        662      0.702      0.962      0.903      0.663
#              anopheles         15         15          1          0     0.0404     0.0336
#                  culex        657        657      0.555      0.954      0.863      0.636
#               culiseta         88         88      0.169      0.466      0.175      0.141
#     japonicus/koreicus         69         69      0.152      0.087      0.127     0.0958
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 11.6ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/train2

# %% [markdown]
# **RT-DETR Model**

# %%
from ultralytics import RTDETR

model = RTDETR("rtdetr-l.pt")

results = model.train(data="/kaggle/working/dataset.yaml", epochs=5, imgsz=640)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/rtdetr-l.pt to 'rtdetr-l.pt'...
# 100%|██████████| 63.4M/63.4M [00:00<00:00, 306MB/s]
# Ultralytics 8.3.96 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=rtdetr-l.pt, data=/kaggle/working/dataset.yaml, epochs=5, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# Overriding model.yaml nc=80 with nc=6
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1     25248  ultralytics.nn.modules.block.HGStem          [3, 32, 48]
#   1                  -1  6    155072  ultralytics.nn.modules.block.HGBlock         [48, 48, 128, 3, 6]
#   2                  -1  1      1408  ultralytics.nn.modules.conv.DWConv           [128, 128, 3, 2, 1, False]
#   3                  -1  6    839296  ultralytics.nn.modules.block.HGBlock         [128, 96, 512, 3, 6]
#   4                  -1  1      5632  ultralytics.nn.modules.conv.DWConv           [512, 512, 3, 2, 1, False]
#   5                  -1  6   1695360  ultralytics.nn.modules.block.HGBlock         [512, 192, 1024, 5, 6, True, False]
#   6                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   7                  -1  6   2055808  ultralytics.nn.modules.block.HGBlock         [1024, 192, 1024, 5, 6, True, True]
#   8                  -1  1     11264  ultralytics.nn.modules.conv.DWConv           [1024, 1024, 3, 2, 1, False]
#   9                  -1  6   6708480  ultralytics.nn.modules.block.HGBlock         [1024, 384, 2048, 5, 6, True, False]
#  10                  -1  1    524800  ultralytics.nn.modules.conv.Conv             [2048, 256, 1, 1, None, 1, 1, False]
#  11                  -1  1    789760  ultralytics.nn.modules.transformer.AIFI      [256, 1024, 8]
#  12                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14                   7  1    262656  ultralytics.nn.modules.conv.Conv             [1024, 256, 1, 1, None, 1, 1, False]
#  15            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  17                  -1  1     66048  ultralytics.nn.modules.conv.Conv             [256, 256, 1, 1]
#  18                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  19                   3  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1, None, 1, 1, False]
#  20            [-2, -1]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  22                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  23            [-1, 17]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  25                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  26            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  27                  -1  3   2232320  ultralytics.nn.modules.block.RepC3           [512, 256, 3]
#  28        [21, 24, 27]  1   7314182  ultralytics.nn.modules.head.RTDETRDecoder    [6, [256, 256, 256]]
# rt-detr-l summary: 457 layers, 32,818,406 parameters, 32,818,406 gradients, 108.0 GFLOPs
#
# Transferred 926/941 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/final_dlp_data/train/labels.cache... 6000 images, 0 backgrounds, 1 corrupt: 100%|██████████| 6000/6000 [00:00<?, ?it/s]
# train: WARNING ⚠️ /kaggle/working/final_dlp_data/train/images/120b30b0-c7db-4f0a-bead-a30424a65453.jpeg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0068]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/final_dlp_data/val/labels.cache... 1500 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1500/1500 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 143 weight(decay=0.0), 206 weight(decay=0.0005), 226 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#   0%|          | 0/375 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#         1/5      13.4G     0.5619      6.747     0.4453         29        640: 100%|██████████| 375/375 [08:27<00:00,  1.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:31<00:00,  1.47it/s]
#                    all       1500       1500      0.843       0.31      0.305      0.219
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#   0%|          | 0/375 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#         2/5      13.4G     0.4052     0.8016     0.2997         33        640: 100%|██████████| 375/375 [08:21<00:00,  1.34s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:31<00:00,  1.48it/s]
#                    all       1500       1500      0.817      0.325      0.295      0.211
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#   0%|          | 0/375 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#         3/5      13.4G     0.3801     0.7709     0.2832         31        640: 100%|██████████| 375/375 [08:19<00:00,  1.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:32<00:00,  1.47it/s]
#                    all       1500       1500      0.516      0.385      0.325      0.231
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#   0%|          | 0/375 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#         4/5      13.4G     0.3696     0.7398     0.2769         24        640: 100%|██████████| 375/375 [08:19<00:00,  1.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:31<00:00,  1.48it/s]
#                    all       1500       1500      0.738      0.358      0.355      0.262
#
#       Epoch    GPU_mem  giou_loss   cls_loss    l1_loss  Instances       Size
#   0%|          | 0/375 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: grid_sampler_2d_backward_cuda does not have a deterministic implementation, but you set 'torch.use_deterministic_algorithms(True, warn_only=True)'. You can file an issue at https://github.com/pytorch/pytorch/issues to help us prioritize adding deterministic support for this operation. (Triggered internally at ../aten/src/ATen/Context.cpp:91.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#         5/5      13.4G     0.3528     0.6987     0.2575         23        640: 100%|██████████| 375/375 [08:18<00:00,  1.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:31<00:00,  1.47it/s]
#                    all       1500       1500      0.874      0.414      0.386      0.292
#
# 5 epochs completed in 0.745 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 66.2MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 66.2MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.96 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# rt-detr-l summary: 302 layers, 31,996,070 parameters, 0 gradients, 103.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:32<00:00,  1.44it/s]
#                    all       1500       1500      0.873      0.415      0.386      0.293
#                aegypti          9          9          1          0          0          0
#             albopictus        662        662      0.899      0.817       0.83      0.608
#              anopheles         15         15          1          0          0          0
#                  culex        657        657      0.904      0.888      0.894      0.662
#               culiseta         88         88      0.436      0.784      0.594      0.485
#     japonicus/koreicus         69         69          1          0          0          0
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.2ms preprocess, 16.9ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/train3

# %% [markdown]
# # Submission

# %%
import pandas as pd
import glob
import os
from ultralytics import YOLO, RTDETR

#Loading the sample submission file
submission_path = "/kaggle/input/dlp-object-detection-week-10/sample_submission.csv"
submission_df = pd.read_csv(submission_path)

#Loading all the trained models: RT-DETR & YOLO
yolo_model = YOLO("/kaggle/working/runs/detect/train2/weights/best.pt")
rtdetr_model = RTDETR("/kaggle/working/runs/detect/train3/weights/best.pt")  

#Path to test images
test_images = glob.glob("/kaggle/working/final_dlp_data/test/images/*.jpeg")

#Class names mapping
class_names = {0: "aegypti", 1: "albopictus", 2: "anopheles", 3: "culex", 4: "culiseta", 5: "japonicus/koreicus"}

#Dictionary to store final results
final_results = {}

# Run inference on test images using both models
for img_path in test_images:
    image_id = os.path.basename(img_path)

    # YOLO inference
    yolo_results = yolo_model(img_path)
    yolo_best_prediction = None

    for result in yolo_results:
        for box in result.boxes:
            conf = box.conf[0].item()
            if yolo_best_prediction is None or conf > yolo_best_prediction["Conf"]:
                x_min, y_min, x_max, y_max = box.xyxy[0].tolist()
                xcenter = (x_min + x_max) / (2 * result.orig_shape[1])
                ycenter = (y_min + y_max) / (2 * result.orig_shape[0])
                width = (x_max - x_min) / result.orig_shape[1]
                height = (y_max - y_min) / result.orig_shape[0]
                cls = int(box.cls[0].item())

                yolo_best_prediction = {
                    "LabelName": class_names[cls],
                    "Conf": conf,
                    "xcenter": xcenter,
                    "ycenter": ycenter,
                    "bbx_width": width,
                    "bbx_height": height
                }

    # RT-DETR inference
    rtdetr_results = rtdetr_model(img_path)
    rtdetr_best_prediction = None

    for result in rtdetr_results:
        for box in result.boxes:
            conf = box.conf[0].item()
            if rtdetr_best_prediction is None or conf > rtdetr_best_prediction["Conf"]:
                x_min, y_min, x_max, y_max = box.xyxy[0].tolist()
                xcenter = (x_min + x_max) / (2 * result.orig_shape[1])
                ycenter = (y_min + y_max) / (2 * result.orig_shape[0])
                width = (x_max - x_min) / result.orig_shape[1]
                height = (y_max - y_min) / result.orig_shape[0]
                cls = int(box.cls[0].item())

                rtdetr_best_prediction = {
                    "LabelName": class_names[cls],
                    "Conf": conf,
                    "xcenter": xcenter,
                    "ycenter": ycenter,
                    "bbx_width": width,
                    "bbx_height": height
                }

    # Select the best prediction between YOLO and RT-DETR
    if yolo_best_prediction and rtdetr_best_prediction:
        final_prediction = yolo_best_prediction if yolo_best_prediction["Conf"] > rtdetr_best_prediction["Conf"] else rtdetr_best_prediction
    elif yolo_best_prediction:
        final_prediction = yolo_best_prediction
    elif rtdetr_best_prediction:
        final_prediction = rtdetr_best_prediction
    else:
        # this is the edge case where I'm assuming both the models didn't provide any predicitons, default predicitons are used
        final_prediction = {
            "LabelName": "aegypti",
            "Conf": 0,
            "xcenter": 0,
            "ycenter": 0,
            "bbx_width": 0,
            "bbx_height": 0
        }

    final_results[image_id] = final_prediction

#Updating submission dataframe with final results
for index, row in submission_df.iterrows():
    image_id = row["ImageID"]
    if image_id in final_results:
        submission_df.at[index, "LabelName"] = final_results[image_id]["LabelName"]
        submission_df.at[index, "Conf"] = final_results[image_id]["Conf"]
        submission_df.at[index, "xcenter"] = final_results[image_id]["xcenter"]
        submission_df.at[index, "ycenter"] = final_results[image_id]["ycenter"]
        submission_df.at[index, "bbx_width"] = final_results[image_id]["bbx_width"]
        submission_df.at[index, "bbx_height"] = final_results[image_id]["bbx_height"]

output_path = "/kaggle/working/dual_submission_final.csv"
submission_df.to_csv(output_path, index=False)

print(f"Submission file saved at: {output_path}")
# Out:
# image 1/1 /kaggle/working/final_dlp_data/test/images/d6a596ab-07a1-4284-88d5-7cc3a08232a1.jpeg: 640x480 1 culex, 57.0ms
# Speed: 3.2ms preprocess, 57.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d6a596ab-07a1-4284-88d5-7cc3a08232a1.jpeg: 640x640 1 culiseta, 45.4ms
# Speed: 3.5ms preprocess, 45.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0d7fda56-9014-4d0e-9802-993925febec0.jpeg: 640x480 1 culex, 18.9ms
# Speed: 2.7ms preprocess, 18.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0d7fda56-9014-4d0e-9802-993925febec0.jpeg: 640x640 1 albopictus, 45.5ms
# Speed: 2.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/abcd1135-de3d-4374-bc38-112b4765fa07.jpeg: 640x480 1 albopictus, 18.9ms
# Speed: 2.7ms preprocess, 18.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/abcd1135-de3d-4374-bc38-112b4765fa07.jpeg: 640x640 1 albopictus, 45.9ms
# Speed: 3.2ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/00fbfad7-9722-4581-831c-79faa576ea7f.jpeg: 640x480 (no detections), 19.0ms
# Speed: 2.8ms preprocess, 19.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/00fbfad7-9722-4581-831c-79faa576ea7f.jpeg: 640x640 1 albopictus, 45.7ms
# Speed: 3.1ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b5bf4381-495a-4631-855d-ea0d0032d2c9.jpeg: 640x480 1 albopictus, 18.9ms
# Speed: 2.3ms preprocess, 18.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b5bf4381-495a-4631-855d-ea0d0032d2c9.jpeg: 640x640 1 albopictus, 45.6ms
# Speed: 2.9ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/304f1fec-2a7e-450a-bc0f-e479bf295c3a.jpeg: 640x480 1 albopictus, 18.9ms
# Speed: 2.7ms preprocess, 18.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/304f1fec-2a7e-450a-bc0f-e479bf295c3a.jpeg: 640x640 1 albopictus, 45.7ms
# Speed: 3.5ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9e4abca6-1b85-48c0-916b-30e690279124.jpeg: 640x288 1 culex, 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9e4abca6-1b85-48c0-916b-30e690279124.jpeg: 640x640 2 culexs, 46.2ms
# Speed: 3.1ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c9cf816e-0761-469c-aecc-ad6a5b7e3550.jpeg: 640x480 1 albopictus, 19.6ms
# Speed: 2.4ms preprocess, 19.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c9cf816e-0761-469c-aecc-ad6a5b7e3550.jpeg: 640x640 1 albopictus, 45.5ms
# Speed: 2.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3b4a1715-45fe-4933-8176-144cf59d3c97.jpeg: 640x384 1 albopictus, 54.6ms
# Speed: 2.1ms preprocess, 54.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3b4a1715-45fe-4933-8176-144cf59d3c97.jpeg: 640x640 1 albopictus, 43.7ms
# Speed: 2.9ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/91271444-27b8-4073-894b-ebbebd60bba5.jpeg: 640x288 2 culexs, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/91271444-27b8-4073-894b-ebbebd60bba5.jpeg: 640x640 1 culiseta, 44.0ms
# Speed: 2.9ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/e6831853-9088-486d-b8f2-8a907a547013.jpeg: 640x416 1 albopictus, 54.7ms
# Speed: 2.4ms preprocess, 54.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/e6831853-9088-486d-b8f2-8a907a547013.jpeg: 640x640 3 albopictuss, 44.4ms
# Speed: 2.9ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d9221f5c-8da1-4fdb-b986-bbbc1f9feb31.jpeg: 448x640 1 albopictus, 53.2ms
# Speed: 2.1ms preprocess, 53.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d9221f5c-8da1-4fdb-b986-bbbc1f9feb31.jpeg: 640x640 1 albopictus, 44.3ms
# Speed: 2.7ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/12822b54-bb03-4806-968b-b7ac6fceda48.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/12822b54-bb03-4806-968b-b7ac6fceda48.jpeg: 640x640 1 culex, 44.9ms
# Speed: 2.9ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d4d6b9ff-1d8e-4f8d-bccb-104af272a62e.jpeg: 640x480 1 culex, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d4d6b9ff-1d8e-4f8d-bccb-104af272a62e.jpeg: 640x640 1 culex, 43.8ms
# Speed: 3.2ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/11924d04-69fe-469d-8d1c-119bc0f0b94f.jpeg: 640x480 1 culex, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/11924d04-69fe-469d-8d1c-119bc0f0b94f.jpeg: 640x640 1 culex, 44.0ms
# Speed: 3.2ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2a651700-0df3-4295-b223-3e53ccf2cc8f.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.4ms preprocess, 17.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2a651700-0df3-4295-b223-3e53ccf2cc8f.jpeg: 640x640 1 albopictus, 43.5ms
# Speed: 2.9ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/8aa3af3a-91a0-4ff9-963d-2d1e0990b352.jpeg: 640x480 1 albopictus, 17.3ms
# Speed: 2.7ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/8aa3af3a-91a0-4ff9-963d-2d1e0990b352.jpeg: 640x640 1 albopictus, 1 culex, 44.2ms
# Speed: 3.2ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/beb40459-7e8c-45cc-91a4-b0946728902f.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/beb40459-7e8c-45cc-91a4-b0946728902f.jpeg: 640x640 1 culiseta, 45.8ms
# Speed: 3.3ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/dced8639-b6bd-4c9d-8713-f6c3541aa908.jpeg: 640x640 1 culex, 22.4ms
# Speed: 2.9ms preprocess, 22.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/dced8639-b6bd-4c9d-8713-f6c3541aa908.jpeg: 640x640 1 culex, 48.4ms
# Speed: 2.8ms preprocess, 48.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/bedca634-f975-4989-8cde-b10adbff48a5.jpeg: 640x480 1 culex, 22.6ms
# Speed: 3.6ms preprocess, 22.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/bedca634-f975-4989-8cde-b10adbff48a5.jpeg: 640x640 1 culex, 44.6ms
# Speed: 3.7ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d6cd68e8-d6af-4c30-8f17-f41c55f65972.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d6cd68e8-d6af-4c30-8f17-f41c55f65972.jpeg: 640x640 1 culex, 43.7ms
# Speed: 3.1ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/223f4665-5350-437e-8d0d-13e4b1ad21bc.jpeg: 448x640 4 culexs, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/223f4665-5350-437e-8d0d-13e4b1ad21bc.jpeg: 640x640 2 culexs, 43.5ms
# Speed: 2.6ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/ffb694d6-aee3-4aff-bde8-74ce94e7c8d2.jpeg: 640x480 1 culex, 17.8ms
# Speed: 2.7ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/ffb694d6-aee3-4aff-bde8-74ce94e7c8d2.jpeg: 640x640 1 culex, 43.6ms
# Speed: 3.1ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/cc534b4e-0cb9-40fa-9aa1-795e2ea77e01.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/cc534b4e-0cb9-40fa-9aa1-795e2ea77e01.jpeg: 640x640 1 albopictus, 43.3ms
# Speed: 2.6ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/90b40ef2-012d-4880-ad0a-4422f0ce8df1.jpeg: 384x640 1 albopictus, 53.3ms
# Speed: 2.2ms preprocess, 53.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/90b40ef2-012d-4880-ad0a-4422f0ce8df1.jpeg: 640x640 1 albopictus, 44.3ms
# Speed: 3.0ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/edc597d1-8b44-4fe5-9e07-4f8f59f38a0c.jpeg: 640x480 1 culex, 17.8ms
# Speed: 2.8ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/edc597d1-8b44-4fe5-9e07-4f8f59f38a0c.jpeg: 640x640 1 culex, 44.1ms
# Speed: 3.2ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/e28a655c-73f5-45cf-8677-97ad2406afce.jpeg: 640x384 1 albopictus, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/e28a655c-73f5-45cf-8677-97ad2406afce.jpeg: 640x640 1 culiseta, 43.5ms
# Speed: 2.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/e2364abc-4bb8-4d30-baa2-05abb4884566.jpeg: 384x640 1 albopictus, 18.3ms
# Speed: 2.3ms preprocess, 18.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/e2364abc-4bb8-4d30-baa2-05abb4884566.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 3.4ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0031063e-716a-4080-934c-77598dc8de72.jpeg: 640x480 1 culex, 17.7ms
# Speed: 2.9ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0031063e-716a-4080-934c-77598dc8de72.jpeg: 640x640 1 culex, 43.5ms
# Speed: 3.2ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/8d370e31-80a1-493c-b300-8592ae7b47fb.jpeg: 608x640 1 albopictus, 53.2ms
# Speed: 2.4ms preprocess, 53.2ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/8d370e31-80a1-493c-b300-8592ae7b47fb.jpeg: 640x640 1 albopictus, 43.7ms
# Speed: 2.5ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b9e42504-5d54-48ff-b2c1-18e43c0666cb.jpeg: 640x320 1 culex, 52.6ms
# Speed: 1.6ms preprocess, 52.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b9e42504-5d54-48ff-b2c1-18e43c0666cb.jpeg: 640x640 1 culex, 44.0ms
# Speed: 2.9ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/460d8d46-2f01-4c0d-8f18-49dadb309388.jpeg: 640x640 1 albopictus, 22.4ms
# Speed: 2.8ms preprocess, 22.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/460d8d46-2f01-4c0d-8f18-49dadb309388.jpeg: 640x640 1 albopictus, 43.5ms
# Speed: 2.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5ef5a1ab-555b-48b9-ae2c-7cd13738dc2d.jpeg: 320x640 1 culex, 53.7ms
# Speed: 2.1ms preprocess, 53.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5ef5a1ab-555b-48b9-ae2c-7cd13738dc2d.jpeg: 640x640 1 albopictus, 44.4ms
# Speed: 3.9ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/78a0332d-4ea3-4ac9-aa27-06a9103ef890.jpeg: 640x288 1 culex, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/78a0332d-4ea3-4ac9-aa27-06a9103ef890.jpeg: 640x640 1 culex, 44.4ms
# Speed: 2.8ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/87868e36-b097-48e2-ac70-29bc67f0fb8b.jpeg: 640x480 1 culex, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/87868e36-b097-48e2-ac70-29bc67f0fb8b.jpeg: 640x640 1 culex, 43.2ms
# Speed: 2.5ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/bd403602-7ced-47f7-b580-90cb8658e043.jpeg: 640x384 6 albopictuss, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/bd403602-7ced-47f7-b580-90cb8658e043.jpeg: 640x640 1 albopictus, 1 culiseta, 43.7ms
# Speed: 3.2ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/081e4b2a-6f6e-46c8-9dc0-65c5372d9eb5.jpeg: 480x640 1 albopictus, 53.3ms
# Speed: 3.2ms preprocess, 53.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/081e4b2a-6f6e-46c8-9dc0-65c5372d9eb5.jpeg: 640x640 1 albopictus, 43.9ms
# Speed: 4.0ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/1ccf5f10-bee6-4047-b750-301b329b04e1.jpeg: 480x640 1 culex, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/1ccf5f10-bee6-4047-b750-301b329b04e1.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 3.2ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/62aeb0d0-2be6-4c81-a4da-6b7fe7d8ff5c.jpeg: 576x640 1 albopictus, 58.4ms
# Speed: 2.7ms preprocess, 58.4ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/62aeb0d0-2be6-4c81-a4da-6b7fe7d8ff5c.jpeg: 640x640 1 albopictus, 43.2ms
# Speed: 2.8ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a58d07c8-da0a-4c77-a06c-f36302293da4.jpeg: 640x480 2 culexs, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a58d07c8-da0a-4c77-a06c-f36302293da4.jpeg: 640x640 1 culex, 43.3ms
# Speed: 3.1ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/09f2fb24-90fa-4667-8ff0-2837d9e2e97b.jpeg: 640x576 1 albopictus, 56.3ms
# Speed: 2.6ms preprocess, 56.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/09f2fb24-90fa-4667-8ff0-2837d9e2e97b.jpeg: 640x640 1 culiseta, 43.3ms
# Speed: 3.0ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/34708894-ff23-4209-bd6f-bcd29dff5415.jpeg: 640x480 1 albopictus, 17.9ms
# Speed: 2.7ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/34708894-ff23-4209-bd6f-bcd29dff5415.jpeg: 640x640 2 albopictuss, 43.2ms
# Speed: 3.3ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a6b631f4-e66e-4350-8d79-8dc43dd2d9d6.jpeg: 640x480 1 albopictus, 1 culex, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a6b631f4-e66e-4350-8d79-8dc43dd2d9d6.jpeg: 640x640 1 culiseta, 43.4ms
# Speed: 3.2ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/416adbc5-427d-4fd1-9beb-507ec140487e.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/416adbc5-427d-4fd1-9beb-507ec140487e.jpeg: 640x640 1 culex, 43.3ms
# Speed: 2.8ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9b58be90-9152-45ea-84c9-6d98a817f086.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9b58be90-9152-45ea-84c9-6d98a817f086.jpeg: 640x640 1 culex, 43.7ms
# Speed: 2.7ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6132cb88-f800-4d16-9c5e-a414b2587c4c.jpeg: 640x480 1 culex, 17.3ms
# Speed: 2.9ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6132cb88-f800-4d16-9c5e-a414b2587c4c.jpeg: 640x640 1 culex, 45.0ms
# Speed: 3.2ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/10fcd07a-ec1a-48d6-b4ba-8891347d4232.jpeg: 640x480 1 albopictus, 17.1ms
# Speed: 2.5ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/10fcd07a-ec1a-48d6-b4ba-8891347d4232.jpeg: 640x640 1 albopictus, 43.2ms
# Speed: 3.1ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2d5f1c98-be09-41b1-a425-5630dd807059.jpeg: 512x640 1 albopictus, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2d5f1c98-be09-41b1-a425-5630dd807059.jpeg: 640x640 1 albopictus, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/04741ad4-6e1c-416d-acd4-b352cf18ebda.jpeg: 640x480 2 culexs, 17.8ms
# Speed: 2.7ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/04741ad4-6e1c-416d-acd4-b352cf18ebda.jpeg: 640x640 1 culex, 44.3ms
# Speed: 3.3ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/221c81b4-db24-4c3d-83ce-1803b3a9d473.jpeg: 480x640 2 culexs, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/221c81b4-db24-4c3d-83ce-1803b3a9d473.jpeg: 640x640 1 culex, 43.9ms
# Speed: 1.9ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a7b2fdb5-e670-46c6-ae2f-efe1ec1917d4.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a7b2fdb5-e670-46c6-ae2f-efe1ec1917d4.jpeg: 640x640 2 culexs, 43.4ms
# Speed: 2.9ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/80dc41c3-280a-4e17-b919-1cf4a294b058.jpeg: 640x480 1 albopictus, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/80dc41c3-280a-4e17-b919-1cf4a294b058.jpeg: 640x640 1 albopictus, 1 culex, 44.1ms
# Speed: 3.5ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/03d6749a-c5b3-45a3-81fa-b9c2f09eb4ba.jpeg: 576x640 1 albopictus, 20.8ms
# Speed: 2.1ms preprocess, 20.8ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/03d6749a-c5b3-45a3-81fa-b9c2f09eb4ba.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 2.7ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9d0d18cb-7466-41ca-bc3b-65f447cb4489.jpeg: 640x320 1 albopictus, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9d0d18cb-7466-41ca-bc3b-65f447cb4489.jpeg: 640x640 1 albopictus, 44.4ms
# Speed: 3.2ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a9d3c3fb-5f5e-4e36-a526-2fa1689b04f7.jpeg: 640x352 1 albopictus, 55.8ms
# Speed: 1.8ms preprocess, 55.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a9d3c3fb-5f5e-4e36-a526-2fa1689b04f7.jpeg: 640x640 1 albopictus, 43.7ms
# Speed: 2.8ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c8ac23aa-048f-448e-9e77-e0525fd386bc.jpeg: 640x384 1 culex, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c8ac23aa-048f-448e-9e77-e0525fd386bc.jpeg: 640x640 1 culex, 43.8ms
# Speed: 2.9ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/ed1bdf6c-31ac-4e75-be11-8ff41bae2423.jpeg: 640x480 1 albopictus, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/ed1bdf6c-31ac-4e75-be11-8ff41bae2423.jpeg: 640x640 1 albopictus, 44.1ms
# Speed: 3.2ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/acd2acef-f7bb-45c6-b854-4ab915d5d7ef.jpeg: 640x640 1 culex, 22.5ms
# Speed: 3.3ms preprocess, 22.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/acd2acef-f7bb-45c6-b854-4ab915d5d7ef.jpeg: 640x640 1 culiseta, 43.7ms
# Speed: 3.1ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/feab7021-ab56-4433-824f-bf2436bdd34f.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/feab7021-ab56-4433-824f-bf2436bdd34f.jpeg: 640x640 1 culex, 43.4ms
# Speed: 3.2ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2406e3a6-505e-4674-b4f6-d73f0543e1d5.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2406e3a6-505e-4674-b4f6-d73f0543e1d5.jpeg: 640x640 1 albopictus, 43.3ms
# Speed: 3.2ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5bf2ded9-068d-4f0f-beb1-1af0ac2457e4.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5bf2ded9-068d-4f0f-beb1-1af0ac2457e4.jpeg: 640x640 1 culex, 43.4ms
# Speed: 3.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c9e0f892-48a5-4438-9b83-f3b4d537b4eb.jpeg: 640x480 1 culex, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c9e0f892-48a5-4438-9b83-f3b4d537b4eb.jpeg: 640x640 1 culiseta, 43.5ms
# Speed: 3.2ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9cab7af0-1278-48c9-977d-ac084881a335.jpeg: 640x480 1 albopictus, 17.3ms
# Speed: 2.6ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/9cab7af0-1278-48c9-977d-ac084881a335.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 3.0ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/83940543-c311-42ae-bff5-b84702a68e03.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/83940543-c311-42ae-bff5-b84702a68e03.jpeg: 640x640 1 culex, 43.6ms
# Speed: 2.6ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/31080987-64d1-4d44-9195-7cfe80fdc324.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/31080987-64d1-4d44-9195-7cfe80fdc324.jpeg: 640x640 1 culiseta, 43.0ms
# Speed: 2.8ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/592ac19b-3055-4944-b0ac-fd35ea1b3f1e.jpeg: 640x320 1 culex, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/592ac19b-3055-4944-b0ac-fd35ea1b3f1e.jpeg: 640x640 1 culex, 43.4ms
# Speed: 3.2ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2eb12e3c-65f7-4527-bc6d-460c4bee21f0.jpeg: 320x640 1 culex, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2eb12e3c-65f7-4527-bc6d-460c4bee21f0.jpeg: 640x640 1 albopictus, 43.8ms
# Speed: 3.3ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6c53439b-11cd-4145-888f-596b6d716aac.jpeg: 320x640 1 albopictus, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6c53439b-11cd-4145-888f-596b6d716aac.jpeg: 640x640 1 albopictus, 45.9ms
# Speed: 3.9ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c258f385-f551-48fb-bcd7-5691b699e33d.jpeg: 640x320 1 albopictus, 17.3ms
# Speed: 2.4ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/c258f385-f551-48fb-bcd7-5691b699e33d.jpeg: 640x640 1 albopictus, 43.7ms
# Speed: 3.3ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/62ca1f73-8df8-4762-8bc6-0fc7ba4bfb9e.jpeg: 640x480 1 culex, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/62ca1f73-8df8-4762-8bc6-0fc7ba4bfb9e.jpeg: 640x640 1 culex, 43.4ms
# Speed: 2.5ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3a3a7aa7-3390-4481-812e-e11455adde48.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3a3a7aa7-3390-4481-812e-e11455adde48.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 2.8ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/07e5213c-e31d-4967-a5a6-7f347457771d.jpeg: 640x320 1 culex, 15.3ms
# Speed: 1.7ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/07e5213c-e31d-4967-a5a6-7f347457771d.jpeg: 640x640 1 culex, 44.8ms
# Speed: 2.8ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6b2af5fb-e8cc-45d8-8721-a8f8422f34da.jpeg: 640x480 1 albopictus, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6b2af5fb-e8cc-45d8-8721-a8f8422f34da.jpeg: 640x640 1 culiseta, 43.3ms
# Speed: 2.6ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/296eeeb2-d677-48b6-8cbe-34d15593d680.jpeg: 640x320 1 culex, 15.2ms
# Speed: 1.7ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/296eeeb2-d677-48b6-8cbe-34d15593d680.jpeg: 640x640 1 culex, 43.4ms
# Speed: 2.8ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a98813d4-a142-4fa6-b84f-c24b1f957be2.jpeg: 640x384 1 culex, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a98813d4-a142-4fa6-b84f-c24b1f957be2.jpeg: 640x640 1 culiseta, 43.8ms
# Speed: 3.0ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5477657a-88d8-47fe-87f5-663ed25f1237.jpeg: 384x640 1 albopictus, 18.4ms
# Speed: 2.2ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5477657a-88d8-47fe-87f5-663ed25f1237.jpeg: 640x640 1 albopictus, 43.7ms
# Speed: 3.4ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3c6eed99-b756-42b3-90a3-4314b448d953.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3c6eed99-b756-42b3-90a3-4314b448d953.jpeg: 640x640 1 culiseta, 43.9ms
# Speed: 2.8ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/03ef458e-8f40-4d42-811b-f3c2db667e12.jpeg: 480x640 3 albopictuss, 1 culex, 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/03ef458e-8f40-4d42-811b-f3c2db667e12.jpeg: 640x640 3 albopictuss, 43.2ms
# Speed: 2.6ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/4fb111a0-27ed-4ebb-b5a4-3fa47b80bfc9.jpeg: 320x640 1 culex, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/4fb111a0-27ed-4ebb-b5a4-3fa47b80bfc9.jpeg: 640x640 1 culex, 44.1ms
# Speed: 2.7ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d79ff754-c00b-433d-9108-571d72832d8d.jpeg: 640x480 2 culexs, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d79ff754-c00b-433d-9108-571d72832d8d.jpeg: 640x640 1 culex, 43.2ms
# Speed: 2.8ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/7c1b9f66-7f86-40b7-9e94-d4c822819f7c.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.9ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/7c1b9f66-7f86-40b7-9e94-d4c822819f7c.jpeg: 640x640 1 culiseta, 45.0ms
# Speed: 3.1ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6a7cb700-2b95-40fb-a36e-1feb6aa274af.jpeg: 640x384 1 albopictus, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6a7cb700-2b95-40fb-a36e-1feb6aa274af.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 2.8ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a909dc81-886e-46b2-a141-8d223b058ab4.jpeg: 480x640 1 albopictus, 1 culex, 17.8ms
# Speed: 2.6ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a909dc81-886e-46b2-a141-8d223b058ab4.jpeg: 640x640 1 albopictus, 43.5ms
# Speed: 3.2ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/490cc534-c39e-42c1-9598-e5fb794723b1.jpeg: 640x480 1 culex, 17.9ms
# Speed: 2.3ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/490cc534-c39e-42c1-9598-e5fb794723b1.jpeg: 640x640 1 culex, 43.7ms
# Speed: 2.9ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0e43f1b1-7bae-4ef7-90da-c192a17d1805.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0e43f1b1-7bae-4ef7-90da-c192a17d1805.jpeg: 640x640 1 albopictus, 52.4ms
# Speed: 3.2ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6317a279-8147-4846-b518-e1492cd4de7c.jpeg: 640x544 2 culexs, 56.3ms
# Speed: 3.1ms preprocess, 56.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6317a279-8147-4846-b518-e1492cd4de7c.jpeg: 640x640 1 culiseta, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/df0b7b23-4b1d-479a-9387-6980d007e563.jpeg: 640x288 1 albopictus, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/df0b7b23-4b1d-479a-9387-6980d007e563.jpeg: 640x640 1 albopictus, 43.0ms
# Speed: 2.9ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a573eb7e-a5cb-479a-8ad4-362df11a7b29.jpeg: 640x480 1 albopictus, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a573eb7e-a5cb-479a-8ad4-362df11a7b29.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 2.7ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/ddff4816-55b0-472f-9074-5815b3d9ee64.jpeg: 384x640 1 culex, 18.4ms
# Speed: 1.9ms preprocess, 18.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/ddff4816-55b0-472f-9074-5815b3d9ee64.jpeg: 640x640 1 culex, 43.6ms
# Speed: 2.8ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0d35ce5f-d723-41ab-b9e5-9ee8c25593ed.jpeg: 448x640 1 albopictus, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0d35ce5f-d723-41ab-b9e5-9ee8c25593ed.jpeg: 640x640 1 albopictus, 43.3ms
# Speed: 2.5ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/f5161716-98a8-48e7-9eac-10afc07d9078.jpeg: 480x640 1 culex, 17.9ms
# Speed: 2.3ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/f5161716-98a8-48e7-9eac-10afc07d9078.jpeg: 640x640 3 culexs, 43.6ms
# Speed: 2.7ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6e4c95cc-247e-4f17-9419-e4b19f6842eb.jpeg: 544x640 2 albopictuss, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6e4c95cc-247e-4f17-9419-e4b19f6842eb.jpeg: 640x640 1 culex, 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/92320f79-6507-4ee9-8231-f4886080a52b.jpeg: 480x640 1 albopictus, 17.9ms
# Speed: 2.6ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/92320f79-6507-4ee9-8231-f4886080a52b.jpeg: 640x640 1 albopictus, 43.3ms
# Speed: 3.2ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/86e7cee3-92ac-40e5-b0dc-457ddf2e795e.jpeg: 640x512 1 albopictus, 53.8ms
# Speed: 2.5ms preprocess, 53.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/86e7cee3-92ac-40e5-b0dc-457ddf2e795e.jpeg: 640x640 1 albopictus, 44.4ms
# Speed: 3.0ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/360213fb-1f44-4d6e-9e71-6a802c7a74b7.jpeg: 640x480 1 culex, 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/360213fb-1f44-4d6e-9e71-6a802c7a74b7.jpeg: 640x640 3 culexs, 43.8ms
# Speed: 3.2ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/fae311fd-a029-4bc5-ada9-e240a2a2bc8d.jpeg: 640x480 2 albopictuss, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/fae311fd-a029-4bc5-ada9-e240a2a2bc8d.jpeg: 640x640 1 albopictus, 46.2ms
# Speed: 3.2ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/4debb54d-274f-41bc-b2a8-ccf75bbceea5.jpeg: 640x320 1 culex, 15.3ms
# Speed: 1.7ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/4debb54d-274f-41bc-b2a8-ccf75bbceea5.jpeg: 640x640 1 culex, 44.0ms
# Speed: 2.9ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/f19f20b8-a542-4555-bd5e-b2de8f0fd2dd.jpeg: 640x640 1 albopictus, 22.3ms
# Speed: 2.5ms preprocess, 22.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/f19f20b8-a542-4555-bd5e-b2de8f0fd2dd.jpeg: 640x640 1 albopictus, 43.1ms
# Speed: 2.4ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a049be38-1760-42f8-9f37-a7d7b8dde450.jpeg: 640x480 1 albopictus, 18.0ms
# Speed: 2.7ms preprocess, 18.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a049be38-1760-42f8-9f37-a7d7b8dde450.jpeg: 640x640 1 culex, 43.5ms
# Speed: 3.2ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3067cee3-cbcc-4329-875b-aa5fc4bb2e38.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3067cee3-cbcc-4329-875b-aa5fc4bb2e38.jpeg: 640x640 1 culex, 44.7ms
# Speed: 3.2ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0ec05b33-b16c-4e23-86c1-538bb037efeb.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0ec05b33-b16c-4e23-86c1-538bb037efeb.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 3.3ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6509d5f5-6f52-4427-831d-6818175f90e2.jpeg: 640x480 1 albopictus, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6509d5f5-6f52-4427-831d-6818175f90e2.jpeg: 640x640 1 albopictus, 43.5ms
# Speed: 2.7ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/1e908540-19be-438c-b28f-b97f4734ac87.jpeg: 384x640 1 culex, 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/1e908540-19be-438c-b28f-b97f4734ac87.jpeg: 640x640 1 culex, 45.3ms
# Speed: 2.5ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/7154c57d-6d79-4c11-bb3b-cc8b74ea09df.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/7154c57d-6d79-4c11-bb3b-cc8b74ea09df.jpeg: 640x640 2 culexs, 44.5ms
# Speed: 3.2ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/94554e5f-37c2-4512-a9bf-e31ff7c55565.jpeg: 640x480 1 culex, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/94554e5f-37c2-4512-a9bf-e31ff7c55565.jpeg: 640x640 1 culex, 43.6ms
# Speed: 3.2ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/532e7a50-448f-4df3-beb7-899766572da3.jpeg: 480x640 1 culex, 17.8ms
# Speed: 2.7ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/532e7a50-448f-4df3-beb7-899766572da3.jpeg: 640x640 2 culexs, 44.2ms
# Speed: 3.4ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/18848e68-9d73-4d5e-9724-9de3de4840a4.jpeg: 640x288 1 culex, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/18848e68-9d73-4d5e-9724-9de3de4840a4.jpeg: 640x640 1 culex, 43.2ms
# Speed: 2.9ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5f6b9da5-95c4-4635-af51-895c2fa32411.jpeg: 640x480 1 albopictus, 17.8ms
# Speed: 2.7ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5f6b9da5-95c4-4635-af51-895c2fa32411.jpeg: 640x640 1 culex, 44.0ms
# Speed: 3.1ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/04d4d98b-4b4d-45d1-924a-82f4c3a9ff27.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.9ms preprocess, 18.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# ...
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6535db4a-3754-4678-a1cf-cd565b5040e6.jpeg: 640x480 1 culex, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6535db4a-3754-4678-a1cf-cd565b5040e6.jpeg: 640x640 1 culex, 43.3ms
# Speed: 2.6ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/929047cf-44d6-4c59-bae6-87110df27cbb.jpeg: 640x480 1 albopictus, 1 culex, 17.1ms
# Speed: 2.8ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/929047cf-44d6-4c59-bae6-87110df27cbb.jpeg: 640x640 1 culex, 43.7ms
# Speed: 3.2ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/da0226ce-ef8f-4217-bd5d-38955a232eab.jpeg: 640x480 1 albopictus, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/da0226ce-ef8f-4217-bd5d-38955a232eab.jpeg: 640x640 1 culiseta, 44.6ms
# Speed: 3.1ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/f471732b-e86a-4b41-b499-33763a42fb2c.jpeg: 640x512 1 culex, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/f471732b-e86a-4b41-b499-33763a42fb2c.jpeg: 640x640 1 culex, 43.5ms
# Speed: 2.5ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/84204b9f-8c10-406d-bdd1-790c4b466521.jpeg: 640x480 1 culex, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/84204b9f-8c10-406d-bdd1-790c4b466521.jpeg: 640x640 1 culex, 44.3ms
# Speed: 2.9ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/fbe9717c-3d69-4529-94ee-f1f4ff48e4b5.jpeg: 640x416 1 culex, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/fbe9717c-3d69-4529-94ee-f1f4ff48e4b5.jpeg: 640x640 1 culex, 44.2ms
# Speed: 2.9ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/98b6fce1-0441-41f2-9f15-ead88b530e80.jpeg: 480x640 1 culex, 17.9ms
# Speed: 2.7ms preprocess, 17.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/98b6fce1-0441-41f2-9f15-ead88b530e80.jpeg: 640x640 1 culex, 43.9ms
# Speed: 3.4ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0f66ea3e-dba5-4424-9ed4-23c5c9419d13.jpeg: 640x480 1 albopictus, 17.8ms
# Speed: 2.8ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0f66ea3e-dba5-4424-9ed4-23c5c9419d13.jpeg: 640x640 1 albopictus, 43.7ms
# Speed: 3.2ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6144b1bd-c016-4f6e-bfdb-c51c43af369e.jpeg: 640x480 1 albopictus, 1 culex, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/6144b1bd-c016-4f6e-bfdb-c51c43af369e.jpeg: 640x640 1 culex, 43.9ms
# Speed: 2.6ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/95be7d42-cb47-4a68-9c07-608421e75b59.jpeg: 640x288 1 albopictus, 14.9ms
# Speed: 1.2ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/95be7d42-cb47-4a68-9c07-608421e75b59.jpeg: 640x640 1 albopictus, 43.0ms
# Speed: 2.7ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a413a7d8-d7cb-436c-9449-08b4e1aa41c1.jpeg: 640x480 1 culex, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/a413a7d8-d7cb-436c-9449-08b4e1aa41c1.jpeg: 640x640 1 culex, 43.0ms
# Speed: 2.9ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5385a6f3-0f06-4d0c-a1d7-7ced89007a5a.jpeg: 448x640 1 culex, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/5385a6f3-0f06-4d0c-a1d7-7ced89007a5a.jpeg: 640x640 1 culex, 43.5ms
# Speed: 2.5ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/fa1f7f19-3f8a-4171-9540-a0d8e4f678ac.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/fa1f7f19-3f8a-4171-9540-a0d8e4f678ac.jpeg: 640x640 1 culex, 43.9ms
# Speed: 3.2ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/71404d0a-642e-492e-b777-06536f63664d.jpeg: 480x640 1 albopictus, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/71404d0a-642e-492e-b777-06536f63664d.jpeg: 640x640 1 albopictus, 43.1ms
# Speed: 2.9ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/7d3e790a-65a6-4029-8522-8865aa0a0aac.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/7d3e790a-65a6-4029-8522-8865aa0a0aac.jpeg: 640x640 1 culex, 43.7ms
# Speed: 2.5ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/92742c4a-c8fd-4e3b-8cfa-60d52f26ba8f.jpeg: 640x640 1 albopictus, 22.4ms
# Speed: 3.2ms preprocess, 22.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/92742c4a-c8fd-4e3b-8cfa-60d52f26ba8f.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 3.1ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b8749af1-2c85-46e3-a8b1-f5a97775e2b9.jpeg: 640x480 1 albopictus, 17.9ms
# Speed: 2.7ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b8749af1-2c85-46e3-a8b1-f5a97775e2b9.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 3.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b24a13f5-59f2-4deb-b77d-543468397b9b.jpeg: 640x480 1 culex, 17.3ms
# Speed: 2.6ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b24a13f5-59f2-4deb-b77d-543468397b9b.jpeg: 640x640 1 culex, 43.1ms
# Speed: 3.2ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/965d6ab0-4799-4ad1-b21d-bff7a85e67ad.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/965d6ab0-4799-4ad1-b21d-bff7a85e67ad.jpeg: 640x640 1 culex, 43.0ms
# Speed: 2.9ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2ff9ef9d-4c6e-4056-b98b-dded3840db1b.jpeg: 640x480 1 albopictus, 17.3ms
# Speed: 2.4ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/2ff9ef9d-4c6e-4056-b98b-dded3840db1b.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 3.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/27d2800b-4eb7-4312-a058-37d227c117aa.jpeg: 640x480 1 culex, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/27d2800b-4eb7-4312-a058-37d227c117aa.jpeg: 640x640 1 culex, 43.0ms
# Speed: 2.9ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/378f79e4-6ca0-4c79-a56d-54b1b7f7e9e2.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/378f79e4-6ca0-4c79-a56d-54b1b7f7e9e2.jpeg: 640x640 1 culex, 43.0ms
# Speed: 2.6ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/670e619f-ed1a-43d2-b2e4-80d74614b893.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/670e619f-ed1a-43d2-b2e4-80d74614b893.jpeg: 640x640 1 culex, 43.8ms
# Speed: 2.9ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d6a66463-38b6-4756-8ea9-dc254ea93c55.jpeg: 480x640 1 albopictus, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d6a66463-38b6-4756-8ea9-dc254ea93c55.jpeg: 640x640 1 albopictus, 43.4ms
# Speed: 2.9ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d74c2888-2727-4dea-b90e-10e2b6d64a37.jpeg: 640x576 1 albopictus, 21.1ms
# Speed: 2.6ms preprocess, 21.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/d74c2888-2727-4dea-b90e-10e2b6d64a37.jpeg: 640x640 1 albopictus, 43.3ms
# Speed: 3.0ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/651b0353-c02e-4f01-b129-53214a6b5378.jpeg: 640x480 1 culex, 18.0ms
# Speed: 2.7ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/651b0353-c02e-4f01-b129-53214a6b5378.jpeg: 640x640 1 culex, 43.4ms
# Speed: 3.2ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/988fe925-5890-44b1-97d6-736d8d6fd9b7.jpeg: 640x480 2 culexs, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/988fe925-5890-44b1-97d6-736d8d6fd9b7.jpeg: 640x640 2 culexs, 43.1ms
# Speed: 2.9ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/91f0117d-7648-4951-ad9c-86c27db235b0.jpeg: 640x480 1 culex, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/91f0117d-7648-4951-ad9c-86c27db235b0.jpeg: 640x640 3 culexs, 44.4ms
# Speed: 2.6ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/120dbc2e-d2f2-4e7f-969c-49055306eece.jpeg: 640x480 2 culexs, 17.2ms
# Speed: 2.5ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/120dbc2e-d2f2-4e7f-969c-49055306eece.jpeg: 640x640 1 albopictus, 2 culexs, 43.6ms
# Speed: 2.9ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3f9877b2-983c-45a2-9784-64a2e2f9607e.jpeg: 640x320 1 culex, 15.5ms
# Speed: 1.7ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/3f9877b2-983c-45a2-9784-64a2e2f9607e.jpeg: 640x640 1 culex, 43.3ms
# Speed: 2.9ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/db5d29ce-5a9c-4b3d-a369-041026c7fc01.jpeg: 640x384 1 albopictus, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/db5d29ce-5a9c-4b3d-a369-041026c7fc01.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 3.2ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b1b977df-dd1e-43fd-9e25-0a21e65990ce.jpeg: 640x320 1 culex, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/b1b977df-dd1e-43fd-9e25-0a21e65990ce.jpeg: 640x640 1 culex, 43.3ms
# Speed: 2.9ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/78d112c6-29f3-45bc-80da-ea4680d75ce0.jpeg: 512x640 1 albopictus, 18.4ms
# Speed: 2.5ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/78d112c6-29f3-45bc-80da-ea4680d75ce0.jpeg: 640x640 1 albopictus, 43.8ms
# Speed: 3.0ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/62e8aa3a-af90-4de0-a537-4ac8dd4f61e5.jpeg: 640x640 1 albopictus, 22.5ms
# Speed: 3.1ms preprocess, 22.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/62e8aa3a-af90-4de0-a537-4ac8dd4f61e5.jpeg: 640x640 1 albopictus, 43.6ms
# Speed: 3.0ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0df08feb-bd58-4288-ba02-c42bb4f9ff2d.jpeg: 640x384 1 culex, 18.3ms
# Speed: 2.3ms preprocess, 18.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/0df08feb-bd58-4288-ba02-c42bb4f9ff2d.jpeg: 640x640 1 culex, 43.7ms
# Speed: 3.2ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/846989e5-ee4b-4ccf-85f2-a3407c5c9fe6.jpeg: 640x480 1 albopictus, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /kaggle/working/final_dlp_data/test/images/846989e5-ee4b-4ccf-85f2-a3407c5c9fe6.jpeg: 640x640 1 albopictus, 44.0ms
# Speed: 3.2ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Submission file saved at: /kaggle/working/dual_submission_final.csv
